# %%
import csv
a=[]
file=open("C:/Users/MUSKAN CYBERTECH/Documents/FINDS.CSV","r")
reader=csv.reader(file)
for i in reader:
    a.append(i)
    print(i)
num_attributes=5    
print("\n the initial value of hypothesis:")  
hypothesis = ['0'] * num_attributes
print(hypothesis)  
for j in range(0,num_attributes):
    hypothesis[j]=a[0][j];
    print("new",hypothesis)
    print("\n find s: finding a maximally specific hypothesis\n")
    print("length of a",len(a))
    for i in range(0,len(a)):
        if a[i][5]=='yes':
            for j in range(0,num_attributes):
                if a[i][j]!=hypothesis[j]:
                    hypothesis[j]='?'
                else:
                    hypothesis[j]=a[i][j]
        print("for training instance no:{0} the hypothesis is".format(i),hypothesis)
    print("\n the maximally specific hypothesis for a given training examples :\n")
    print(hypothesis)
# Out:
# ['NO', 'NO', 'NO', 'NO', 'NO', '0']
# ['YES', 'YES', 'YES', 'YES', 'YES', '1']
# ['YES', 'YES', 'NO', 'YES', 'NO', '0']
# ['YES', 'NO', 'YES', 'YES', 'YES', '1']
# ['YES', 'YES', 'YES', 'YES', 'YES', '1']
# ['NO', 'YES', 'NO', 'NO', 'YES', '0']
# ['YES', 'NO', 'YES', 'YES', 'YES', '1']
# ['YES', 'NO', 'YES', 'YES', 'YES', '1']
# ['NO', 'YES', 'YES', 'YES', 'YES', '1']
# ['YES', 'YES', 'YES', 'YES', 'YES', '1']
# ['NO', 'YES', 'NO', 'YES', 'YES', '0']
# ['NO', 'YES', 'YES', 'YES', 'YES', '1']
# ['NO', 'YES', 'YES', 'NO', 'NO', '0']
# ['YES', 'YES', 'NO', 'NO', 'NO', '0']
#
#  the initial value of hypothesis:
# ['0', '0', '0', '0', '0']
# new ['NO', '0', '0', '0', '0']
#
#  find s: finding a maximally specific hypothesis
#
# length of a 14
# for training instance no:0 the hypothesis is ['NO', '0', '0', '0', '0']
# for training instance no:1 the hypothesis is ['NO', '0', '0', '0', '0']
# for training instance no:2 the hypothesis is ['NO', '0', '0', '0', '0']
# for training instance no:3 the hypothesis is ['NO', '0', '0', '0', '0']
# for training instance no:4 the hypothesis is ['NO', '0', '0', '0', '0']
# for training instance no:5 the hypothesis is ['NO', '0', '0', '0', '0']
# for training instance no:6 the hypothesis is ['NO', '0', '0', '0', '0']
# for training instance no:7 the hypothesis is ['NO', '0', '0', '0', '0']
# for training instance no:8 the hypothesis is ['NO', '0', '0', '0', '0']
# for training instance no:9 the hypothesis is ['NO', '0', '0', '0', '0']
# for training instance no:10 the hypothesis is ['NO', '0', '0', '0', '0']
# for training instance no:11 the hypothesis is ['NO', '0', '0', '0', '0']
# for training instance no:12 the hypothesis is ['NO', '0', '0', '0', '0']
# for training instance no:13 the hypothesis is ['NO', '0', '0', '0', '0']
#
#  the maximally specific hypothesis for a given training examples :
#
# ['NO', '0', '0', '0', '0']
# new ['NO', 'NO', '0', '0', '0']
#
#  find s: finding a maximally specific hypothesis
#
# length of a 14
# for training instance no:0 the hypothesis is ['NO', 'NO', '0', '0', '0']
# for training instance no:1 the hypothesis is ['NO', 'NO', '0', '0', '0']
# for training instance no:2 the hypothesis is ['NO', 'NO', '0', '0', '0']
# for training instance no:3 the hypothesis is ['NO', 'NO', '0', '0', '0']
# for training instance no:4 the hypothesis is ['NO', 'NO', '0', '0', '0']
# for training instance no:5 the hypothesis is ['NO', 'NO', '0', '0', '0']
# for training instance no:6 the hypothesis is ['NO', 'NO', '0', '0', '0']
# for training instance no:7 the hypothesis is ['NO', 'NO', '0', '0', '0']
# for training instance no:8 the hypothesis is ['NO', 'NO', '0', '0', '0']
# for training instance no:9 the hypothesis is ['NO', 'NO', '0', '0', '0']
# for training instance no:10 the hypothesis is ['NO', 'NO', '0', '0', '0']
# for training instance no:11 the hypothesis is ['NO', 'NO', '0', '0', '0']
# for training instance no:12 the hypothesis is ['NO', 'NO', '0', '0', '0']
# for training instance no:13 the hypothesis is ['NO', 'NO', '0', '0', '0']
#
#  the maximally specific hypothesis for a given training examples :
#
# ['NO', 'NO', '0', '0', '0']
# new ['NO', 'NO', 'NO', '0', '0']
#
#  find s: finding a maximally specific hypothesis
#
# length of a 14
# for training instance no:0 the hypothesis is ['NO', 'NO', 'NO', '0', '0']
# for training instance no:1 the hypothesis is ['NO', 'NO', 'NO', '0', '0']
# for training instance no:2 the hypothesis is ['NO', 'NO', 'NO', '0', '0']
# for training instance no:3 the hypothesis is ['NO', 'NO', 'NO', '0', '0']
# for training instance no:4 the hypothesis is ['NO', 'NO', 'NO', '0', '0']
# for training instance no:5 the hypothesis is ['NO', 'NO', 'NO', '0', '0']
# for training instance no:6 the hypothesis is ['NO', 'NO', 'NO', '0', '0']
# for training instance no:7 the hypothesis is ['NO', 'NO', 'NO', '0', '0']
# for training instance no:8 the hypothesis is ['NO', 'NO', 'NO', '0', '0']
# for training instance no:9 the hypothesis is ['NO', 'NO', 'NO', '0', '0']
# for training instance no:10 the hypothesis is ['NO', 'NO', 'NO', '0', '0']
# for training instance no:11 the hypothesis is ['NO', 'NO', 'NO', '0', '0']
# for training instance no:12 the hypothesis is ['NO', 'NO', 'NO', '0', '0']
# for training instance no:13 the hypothesis is ['NO', 'NO', 'NO', '0', '0']
#
#  the maximally specific hypothesis for a given training examples :
#
# ['NO', 'NO', 'NO', '0', '0']
# new ['NO', 'NO', 'NO', 'NO', '0']
#
#  find s: finding a maximally specific hypothesis
#
# length of a 14
# for training instance no:0 the hypothesis is ['NO', 'NO', 'NO', 'NO', '0']
# for training instance no:1 the hypothesis is ['NO', 'NO', 'NO', 'NO', '0']
# for training instance no:2 the hypothesis is ['NO', 'NO', 'NO', 'NO', '0']
# for training instance no:3 the hypothesis is ['NO', 'NO', 'NO', 'NO', '0']
# for training instance no:4 the hypothesis is ['NO', 'NO', 'NO', 'NO', '0']
# for training instance no:5 the hypothesis is ['NO', 'NO', 'NO', 'NO', '0']
# for training instance no:6 the hypothesis is ['NO', 'NO', 'NO', 'NO', '0']
# for training instance no:7 the hypothesis is ['NO', 'NO', 'NO', 'NO', '0']
# for training instance no:8 the hypothesis is ['NO', 'NO', 'NO', 'NO', '0']
# for training instance no:9 the hypothesis is ['NO', 'NO', 'NO', 'NO', '0']
# for training instance no:10 the hypothesis is ['NO', 'NO', 'NO', 'NO', '0']
# for training instance no:11 the hypothesis is ['NO', 'NO', 'NO', 'NO', '0']
# for training instance no:12 the hypothesis is ['NO', 'NO', 'NO', 'NO', '0']
# for training instance no:13 the hypothesis is ['NO', 'NO', 'NO', 'NO', '0']
#
#  the maximally specific hypothesis for a given training examples :
#
# ['NO', 'NO', 'NO', 'NO', '0']
# new ['NO', 'NO', 'NO', 'NO', 'NO']
#
#  find s: finding a maximally specific hypothesis
#
# length of a 14
# for training instance no:0 the hypothesis is ['NO', 'NO', 'NO', 'NO', 'NO']
# for training instance no:1 the hypothesis is ['NO', 'NO', 'NO', 'NO', 'NO']
# for training instance no:2 the hypothesis is ['NO', 'NO', 'NO', 'NO', 'NO']
# for training instance no:3 the hypothesis is ['NO', 'NO', 'NO', 'NO', 'NO']
# for training instance no:4 the hypothesis is ['NO', 'NO', 'NO', 'NO', 'NO']
# for training instance no:5 the hypothesis is ['NO', 'NO', 'NO', 'NO', 'NO']
# for training instance no:6 the hypothesis is ['NO', 'NO', 'NO', 'NO', 'NO']
# for training instance no:7 the hypothesis is ['NO', 'NO', 'NO', 'NO', 'NO']
# for training instance no:8 the hypothesis is ['NO', 'NO', 'NO', 'NO', 'NO']
# for training instance no:9 the hypothesis is ['NO', 'NO', 'NO', 'NO', 'NO']
# for training instance no:10 the hypothesis is ['NO', 'NO', 'NO', 'NO', 'NO']
# for training instance no:11 the hypothesis is ['NO', 'NO', 'NO', 'NO', 'NO']
# for training instance no:12 the hypothesis is ['NO', 'NO', 'NO', 'NO', 'NO']
# for training instance no:13 the hypothesis is ['NO', 'NO', 'NO', 'NO', 'NO']
#
#  the maximally specific hypothesis for a given training examples :
#
# ['NO', 'NO', 'NO', 'NO', 'NO']
